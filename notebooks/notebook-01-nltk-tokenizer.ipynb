# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %% [markdown]
#  NLP - Tokenization
# For it need to downloada datset

# %%
sentence = """At eight o'clock on Thursday morning
... Arthur didn't feel very good."""

# %%
# nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/devs/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# The difference between .split and the nltk tokenizer is: the split works by split with the spaces only

# %%
sentence.split()
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  '...',
#  'Arthur',
#  "didn't",
#  'feel',
#  'very',
#  'good.']

# %%
tokens = word_tokenize(sentence)

# %%
tokens
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  '...',
#  'Arthur',
#  'did',
#  "n't",
#  'feel',
#  'very',
#  'good',
#  '.']

# %%
sentences = sent_tokenize(sentence)
sentences
# Out:
# ["At eight o'clock on Thursday morning\n... Arthur didn't feel very good."]
