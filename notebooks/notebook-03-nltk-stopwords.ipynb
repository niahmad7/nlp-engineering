# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/devs/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
sentence = """The quick brown fox jumps over the lazy dog."""

# %%
words = word_tokenize(sentence)
stop_words = set(stopwords.words('english'))

filtered_words = [w for w in words if w.lower() not in stop_words and w.isalnum()]

unfiltered_words = [w for w in words if w.lower() in stop_words or not w.isalnum()]

print(filtered_words)
print(unfiltered_words)
# Out:
# ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog']
# ['The', 'over', 'the', '.']
